# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting mapclassify==2.8.1
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify==2.8.1->-r ./requirements.txt (line 2)) (2.1.4)
# Collecting networkx>=2.7
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify==2.8.1->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: numpy>=1.23 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify==2.8.1->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: scikit-learn>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mapclassify==2.8.1->-r ./requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r ./requirements.txt (line 2)) (1.16.0)
# Installing collected packages: networkx, mapclassify
# Successfully installed mapclassify-2.8.1 networkx-3.2.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f5e651ad-5eee-402d-a771-d60f326b92f5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
